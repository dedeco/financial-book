# %%
import pandas as pd

# %% [markdown]
# ### Helpers functions

# %%
def parse_to_pd(file, sep=';', decimal="."):
    df = pd.read_csv(file, skiprows=[1], sep=sep, decimal=decimal)
    return df

# %% [markdown]
# ### Explore

# %%
df = parse_to_pd("../temp/processed/Timecards_2ffbfc36-f864-4d60-9b66-26e14844d04e")

# %%
df.head(3)
# Out:
#     Timecard: Timecard Id Timecard Split: Timecard Split Id  \
# 0  TCH-12-30-2019-2838595             TC-12-30-2019-3186688
# 1  TCH-01-03-2020-2849451             TC-01-03-2020-3206168
# 2  TCH-01-06-2020-2854825             TC-01-06-2020-3216126
#
#                 Project         Sub-Project    Project Manager  \
# 0  Brava Juliett - 2020  Delivery Assurance  Georgina Reategui
# 1  Brava Juliett - 2020  Delivery Assurance  Georgina Reategui
# 2  Brava Juliett - 2020  Delivery Assurance  Georgina Reategui
#
#                                        Assignment Timecard: Owner Name  \
# 0  Brava Juliett - 2020-Belo Horizonte-2020-01-01     Weslley Oliveira
# 1  Brava Juliett - 2020-Belo Horizonte-2020-01-01      Priscilla Lopes
# 2  Brava Juliett - 2020-Belo Horizonte-2020-01-01      Gabriel Ribeiro
#
#    Start Date    End Date  Billable  ... Friday Hours Saturday Hours  \
# 0  01/01/2020  05/01/2020         1  ...         8,00           0,00
# ...

# %%
df = parse_to_pd("../temp/input/Account_Projects_88e569c8-eafa-4929-88eb-81fec96977dc.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10946 entries, 0 to 10945
# Data columns (total 20 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Account: Account Name                10946 non-null  object
#  1   Account: Client Code                 10936 non-null  object
#  2   Account: Region                      3723 non-null   object
#  3   ClientProj Code                      10946 non-null  object
#  4   Project: Project Name                10946 non-null  object
#  5   Project Manager                      10478 non-null  object
#  6   Region                               10929 non-null  object
#  7   Location                             3 non-null      object
#  8   Active                               10946 non-null  int64
#  9   Billable                             10946 non-null  int64
#  10  Start Date                           10925 non-null  object
# ...

# %%
df = parse_to_pd("../temp/input/Resource_Assignments_917f0f45-7df6-4c17-b79b-108505fed208.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15169 entries, 0 to 15168
# Data columns (total 14 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Resource Request                      15016 non-null  object
#  1   Resource: Full Name                   15169 non-null  object
#  2   Resource: Email                       15169 non-null  object
#  3   Project                               15169 non-null  object
#  4   Assignment: Assignment Name           15169 non-null  object
#  5   Assignment: ID                        15169 non-null  object
#  6   API Assignment Correlation ID         0 non-null      float64
#  7   Resource: Account ID                  15169 non-null  object
#  8   Resource: Employee ID                 15169 non-null  int64
#  9   Resource: Account ID (18 Characters)  15169 non-null  object
#  10  Resource: Client Code                 0 non-null      float64
# ...

# %%
df = parse_to_pd("../temp/input/input_Accounts_Projects_Time.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84229 entries, 0 to 84228
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Account ID         84229 non-null  object
#  1   Account Name       84229 non-null  object
#  2   Project ID         84229 non-null  object
#  3   Project Code       84229 non-null  object
#  4   Project Name       84229 non-null  object
#  5   Timecard Id        84229 non-null  object
#  6   Timecard Split Id  84229 non-null  object
#  7   End Date           84229 non-null  object
# dtypes: object(8)
# memory usage: 5.1+ MB

# %%
df = parse_to_pd("../temp/input/input_Assignment_Beach.csv",sep=',', decimal=",")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 719 entries, 0 to 718
# Data columns (total 30 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Employee ID                 719 non-null    int64
#  1   Consultant                  719 non-null    object
#  2   Gender                      719 non-null    object
#  3   Role                        719 non-null    object
#  4   Grade                       719 non-null    object
#  5   Skills                      541 non-null    object
#  6   Assignment Start Date       553 non-null    object
#  7   End Date                    553 non-null    object
#  8   Effort(%)                   553 non-null    float64
#  9   Probability(%)              553 non-null    float64
#  10  Staffing Office             719 non-null    object
#  11  Working Office              719 non-null    object
#  12  Project                     553 non-null    object
# ...

# %%
df.head(3)
# Out:
#    Employee ID          Consultant Gender       Role              Grade  \
# 0        25392  Guilherme Silveira    Man  Developer  Senior Consultant
# 1        27232   Matheus Marchezan    Man  Developer  Senior Consultant
# 2        26381         Filipe Daré    Man  Developer    Lead Consultant
#
#                                               Skills Assignment Start Date  \
# 0  [Expert]: English,Portuguese;\n[Experienced]: ...            2020-01-01
# 1  [Expert]: Portuguese;\n[Experienced]: Java;\n[...            2020-03-09
# 2  [Expert]: AngularJS ,C#,HTML,Portuguese;\n[Exp...            2020-03-09
#
#      End Date  Effort(%)  Probability(%)  ... Opportunity Probability(%)  \
# 0  2020-12-31      100.0           100.0  ...                      100.0
# 1  2020-12-31      100.0           100.0  ...                      100.0
# 2  2020-12-31      100.0           100.0  ...                      100.0
#
#    Close Date   Primary Service Forecast Category Project Start Date  \
# ...
